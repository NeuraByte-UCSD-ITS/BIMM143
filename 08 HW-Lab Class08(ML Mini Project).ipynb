# %% [markdown]
# > NAME: $\color{red}{\text{    Edwin Ruiz    }}$
# >
# > PID: $\color{red}{\text{    A17136339     }}$

# %% [markdown]
# # 1. Exploratory data analysis

# %%
# Save your input data file into your Project directory
fna.data <- "WisconsinCancer.csv"

# Complete the following code to input the data and store as wisc.df
wisc.df <- read.csv(fna.data, row.names=1)

wisc.df
# Out:
#          diagnosis radius_mean texture_mean perimeter_mean area_mean
# 842302   M         17.990      10.38        122.80         1001.0
# 842517   M         20.570      17.77        132.90         1326.0
# 84300903 M         19.690      21.25        130.00         1203.0
# 84348301 M         11.420      20.38         77.58          386.1
# 84358402 M         20.290      14.34        135.10         1297.0
# 843786   M         12.450      15.70         82.57          477.1
# 844359   M         18.250      19.98        119.60         1040.0
# 84458202 M         13.710      20.83         90.20          577.9
# 844981   M         13.000      21.82         87.50          519.8
# 84501001 M         12.460      24.04         83.97          475.9
# 845636   M         16.020      23.24        102.70          797.8
# 84610002 M         15.780      17.89        103.60          781.0
# 846226   M         19.170      24.80        132.40         1123.0
# ...

# %%
# We can use -1 here to remove the first column
wisc.data <- wisc.df[,-1]

# Create diagnosis vector for later 
diagnosis <- factor(wisc.df$diagnosis)

# %% [markdown]
# ### Q1. How many observations are in this dataset?

# %%
nrow(wisc.data)
# Out:
# [1] 569

# %% [markdown]
# ### Q2. How many of the observations have a malignant diagnosis?

# %%
sum(diagnosis == "M")
# Out:
# [1] 212

# %% [markdown]
# ### Q3. How many variables/features in the data are suffixed with _mean?

# %%
length(grep("_mean", names(wisc.data)))
# Out:
# [1] 10

# %% [markdown]
# # 2. Principal Component Analysis
#
# ## Performing PCA

# %%
# Check column means and standard deviations
colMeans(wisc.data)

apply(wisc.data,2,sd)
# Out:
#             radius_mean            texture_mean          perimeter_mean
#            1.412729e+01            1.928965e+01            9.196903e+01
#               area_mean         smoothness_mean        compactness_mean
#            6.548891e+02            9.636028e-02            1.043410e-01
#          concavity_mean     concave.points_mean           symmetry_mean
#            8.879932e-02            4.891915e-02            1.811619e-01
#  fractal_dimension_mean               radius_se              texture_se
#            6.279761e-02            4.051721e-01            1.216853e+00
#            perimeter_se                 area_se           smoothness_se
#            2.866059e+00            4.033708e+01            7.040979e-03
#          compactness_se            concavity_se       concave.points_se
#            2.547814e-02            3.189372e-02            1.179614e-02
#             symmetry_se    fractal_dimension_se            radius_worst
# ...

# %%
# Perform PCA on wisc.data by completing the following code
wisc.pr <- prcomp(wisc.data, scale. = TRUE)

# Look at summary of results
summary(wisc.pr)
# Out:
# Importance of components:
#                           PC1    PC2     PC3     PC4     PC5     PC6     PC7
# Standard deviation     3.6444 2.3857 1.67867 1.40735 1.28403 1.09880 0.82172
# Proportion of Variance 0.4427 0.1897 0.09393 0.06602 0.05496 0.04025 0.02251
# Cumulative Proportion  0.4427 0.6324 0.72636 0.79239 0.84734 0.88759 0.91010
#                            PC8    PC9    PC10   PC11    PC12    PC13    PC14
# Standard deviation     0.69037 0.6457 0.59219 0.5421 0.51104 0.49128 0.39624
# Proportion of Variance 0.01589 0.0139 0.01169 0.0098 0.00871 0.00805 0.00523
# Cumulative Proportion  0.92598 0.9399 0.95157 0.9614 0.97007 0.97812 0.98335
#                           PC15    PC16    PC17    PC18    PC19    PC20   PC21
# Standard deviation     0.30681 0.28260 0.24372 0.22939 0.22244 0.17652 0.1731
# Proportion of Variance 0.00314 0.00266 0.00198 0.00175 0.00165 0.00104 0.0010
# Cumulative Proportion  0.98649 0.98915 0.99113 0.99288 0.99453 0.99557 0.9966
# ...

# %% [markdown]
# ### Q4. From your results, what proportion of the original variance is captured by the first principal components (PC1)?

# %% [markdown]
# 0.4427 or 44.27%

# %% [markdown]
# ### Q5. How many principal components (PCs) are required to describe at least 70% of the original variance in the data?

# %%
pcs_70 <- min(which(cumsum(wisc.pr$sdev^2 / sum(wisc.pr$sdev^2)) >= 0.7))
pcs_70
# Out:
# [1] 3

# %% [markdown]
# ### Q6. How many principal components (PCs) are required to describe at least 90% of the original variance in the data?

# %%
pcs_90 <- min(which(cumsum(wisc.pr$sdev^2 / sum(wisc.pr$sdev^2)) >= 0.9))
pcs_90
# Out:
# [1] 7

# %% [markdown]
# ## Interpreting PCA results
#
# ### Q7. What stands out to you about this plot? Is it easy or difficult to understand? Why?
#
# Everything seems to be at the center of this black cluster and it is difficult to interpret because it is not easy to determine which data belongs do what cluster in this plot

# %%
biplot(wisc.pr, cex = 0.7)
# Out:
# plot without title

# %%
# Scatter plot observations by components 1 and 2
plot(wisc.pr$x[,c(1,2)], col = diagnosis, 
     xlab = "PC1", ylab = "PC2")
# Out:
# plot without title

# %% [markdown]
# ### Q8. Generate a similar plot for principal components 1 and 3. What do you notice about these plots?

# %%
# Repeat for components 1 and 3
plot(wisc.pr$x[,c(1,3)], col = diagnosis, 
     xlab = "PC1", ylab = "PC3")
# Out:
# plot without title

# %% [markdown]
# The only difference is in PC3 which shows the variability in the data and PC1 remains consistent overall

# %%
# Create a data frame from PCA results for plotting
df <- as.data.frame(wisc.pr$x)
df$diagnosis <- diagnosis

# Load the ggplot2 package
library(ggplot2)

# Make a scatter plot colored by diagnosis
ggplot(df) + 
  aes(PC1, PC2, col=diagnosis) + 
  geom_point()
# Out:
# plot without title

# %% [markdown]
# ## Variance explained

# %%
# Calculate variance of each component
pr.var <- wisc.pr$sdev^2
head(pr.var)

# Variance explained by each principal component: pve
pve <- pr.var / sum(pr.var)

# Plot variance explained for each principal component
plot(pve, xlab = "Principal Component", 
     ylab = "Proportion of Variance Explained", 
     ylim = c(0, 1), type = "o")
# Out:
# [1] 13.281608  5.691355  2.817949  1.980640  1.648731  1.207357
# plot without title

# %%
# Alternative scree plot of the same data, note data driven y-axis
barplot(pve, ylab = "Precent of Variance Explained",
     names.arg=paste0("PC",1:length(pve)), las=2, axes = FALSE)
axis(2, at=pve, labels=round(pve,2)*100 )
# Out:
# plot without title

# %%
## ggplot based graph
install.packages("factoextra")
library(factoextra)
fviz_eig(wisc.pr, addlabels = TRUE)
# Out:
# The downloaded binary packages are in
# 	/var/folders/vw/6c5wjngs433234dthdjypz800000gn/T//RtmpaUnjdT/downloaded_packages
# Welcome! Want to learn more? See two factoextra-related books at https://goo.gl/ve3WBa
# plot without title

# %% [markdown]
# ## Communicating PCA results
#
# ### Q9. For the first principal component, what is the component of the loading vector (i.e. `wisc.pr$rotation[,1]`) for the feature concave.points_mean?

# %%
wisc.pr$rotation["concave.points_mean", 1]
# Out:
# [1] -0.2608538

# %% [markdown]
# ### Q10. What is the minimum number of principal components required to explain 80% of the variance of the data?

# %%
pcs_80 <- min(which(cumsum(wisc.pr$sdev^2 / sum(wisc.pr$sdev^2)) >= 0.8))
pcs_80
# Out:
# [1] 5

# %% [markdown]
# ## 3. Hierarchical clustering

# %%
data.scaled <- scale(wisc.data)
data.dist <- dist(data.scaled)
wisc.hclust <- hclust(data.dist, method="complete")

# %% [markdown]
# ## Results of hierarchical clustering
#
# ### Q11. Using the plot() and abline() functions, what is the height at which the clustering model has 4 clusters?

# %%
plot(wisc.hclust)
abline(h=19, col="red", lty=2)
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# ## Selecting number of clusters

# %%
wisc.hclust.clusters <- cutree(wisc.hclust, k=4)
table(wisc.hclust.clusters, diagnosis)
# Out:
#                     diagnosis
# wisc.hclust.clusters   B   M
#                    1  12 165
#                    2   2   5
#                    3 343  40
#                    4   0   2

# %% [markdown]
# ### Q12. Can you find a better cluster vs diagnoses match by cutting into a different number of clusters between 2 and 10?

# %% [markdown]
# $$
# \begin{array}{c|cc}
# \text{clusters} & \text{B} & \text{M} \\
# \hline
# 1 & 357 & 210 \\
# 2 & 0 & 2 \\
# \end{array}
# $$

# %%
cluster_matches <- sapply(2:10, function(k) table(cutree(wisc.hclust, k), diagnosis))
cluster_matches
# Out:
# [[1]]
#    diagnosis
#       B   M
#   1 357 210
#   2   0   2
#
# [[2]]
#    diagnosis
#       B   M
#   1 355 205
#   2   2   5
#   3   0   2
#
# [[3]]
#    diagnosis
#       B   M
#   1  12 165
#   2   2   5
#   3 343  40
#   4   0   2
#
# [[4]]
#    diagnosis
#       B   M
#   1  12 165
#   2   0   5
#   3 343  40
#   4   2   0
#   5   0   2
#
# [[5]]
#    diagnosis
#       B   M
#   1  12 165
#   2   0   5
#   3 331  39
#   4   2   0
#   5  12   1
#   6   0   2
#
# [[6]]
#    diagnosis
#       B   M
#   1  12 165
#   2   0   3
#   3 331  39
#   4   2   0
#   5  12   1
#   6   0   2
#   7   0   2
#
# [[7]]
#    diagnosis
#       B   M
#   1  12  86
#   2   0  79
#   3   0   3
#   4 331  39
#   5   2   0
#   6  12   1
#   7   0   2
#   8   0   2
#
# [[8]]
#    diagnosis
#       B   M
#   1  12  86
#   2   0  79
#   3   0   3
#   4 331  39
#   5   2   0
#   6  12   0
#   7   0   2
#   8   0   2
#   9   0   1
#
# [[9]]
#     diagnosis
#        B   M
#   1   12  86
#   2    0  59
# ...

# %% [markdown]
# ## Using different methods
#
# ### Q13. Which method gives your favorite results for the same data.dist dataset? Explain your reasoning.
#
# - I like the Ward.D2 method because it not only visually organizes the data but it also makes it easier to interpret the results, although we would have to zoom in to the results to determine this.
#
# https://www.rdocumentation.org/packages/stats/versions/3.6.2/topics/hclust

# %%
wisc.pr.hclust <- hclust(dist(wisc.pr$x), method="ward.D2")
plot(wisc.pr.hclust, main="Ward.D2 Method", sub="", xlab="", ylab="Height")
# Out:
# Plot with title “Ward.D2 Method”

# %% [markdown]
# # 4. OPTIONAL: K-means clustering
#
# ## K-means clustering and comparing results

# %%
wisc.km <- kmeans(scale(wisc.data), centers=2, nstart=20)
table(wisc.km$cluster, diagnosis)
# Out:
#    diagnosis
#       B   M
#   1  14 175
#   2 343  37

# %% [markdown]
# ### Q14. How well does k-means separate the two diagnoses? How does it compare to your hclust results?
#
# It is good, it almost separates malignant and benign cases

# %%
table(wisc.km$cluster, diagnosis)
# Out:
#    diagnosis
#       B   M
#   1  14 175
#   2 343  37

# %% [markdown]
# # 5. Combining methods
#
# ## Clustering on PCA results

# %%
grps <- cutree(wisc.pr.hclust, k=2)
table(grps)
table(grps, diagnosis)
plot(wisc.pr$x[,1:2], col=grps)
plot(wisc.pr$x[,1:2], col=diagnosis)
# Out:
# grps
#   1   2
# 184 385
#     diagnosis
# grps   B   M
#    1  20 164
#    2 337  48
# plot without title
# plot without title

# %%
g <- as.factor(grps)
levels(g)

g <- relevel(g,2)
levels(g)

# Plot using our re-ordered factor 
plot(wisc.pr$x[,1:2], col=g)
# Out:
# [1] "1" "2"
# [1] "2" "1"
# plot without title

# %%
library(rgl)
plot3d(wisc.pr$x[,1:3], xlab="PC 1", ylab="PC 2", zlab="PC 3", cex=1.5, size=1, type="s", col=grps)

## Use the distance along the first 7 PCs for clustering i.e. wisc.pr$x[, 1:7]
wisc.pr.hclust <- hclust(dist(wisc.pr$x[, 1:7]), method="ward.D2")

wisc.pr.hclust.clusters <- cutree(wisc.pr.hclust, k=2)
# Out:
# Warning message in rgl.init(initValue, onlyNULL):
# “RGL: unable to open X11 display”
# Warning message:
# “'rgl.init' failed, running with 'rgl.useNULL = TRUE'.”

# %% [markdown]
# ### Q15. How well does the newly created model with four clusters separate out the two diagnoses?
#
# It is not that great, rather it is mixed

# %%
# Compare to actual diagnoses
table(wisc.pr.hclust.clusters, diagnosis)
# Out:
#                        diagnosis
# wisc.pr.hclust.clusters   B   M
#                       1  28 188
#                       2 329  24

# %% [markdown]
# ### Q16. How well do the k-means and hierarchical clustering models you created in previous sections (i.e. before PCA) do in terms of separating the diagnoses? Again, use the table() function to compare the output of each model ( wisc.km$cluster and wisc.hclust.clusters ) with the vector containing the actual diagnoses.
#
# K-means shows to be better than hierarchical clustering

# %%
table(wisc.km$cluster, diagnosis)
table(wisc.hclust.clusters, diagnosis)
# Out:
#    diagnosis
#       B   M
#   1  14 175
#   2 343  37
#                     diagnosis
# wisc.hclust.clusters   B   M
#                    1  12 165
#                    2   2   5
#                    3 343  40
#                    4   0   2

# %% [markdown]
# ## 6. Sensitivity/Specificity

# %% [markdown]
# ### Q17. Which of your analysis procedures resulted in a clustering model with the best specificity? How about sensitivity?
#
# Hierarchical Clustering is best for specificity
# - Specificity = $\frac{TN}{TN + FP} = \frac{343}{343 + (357 - 343)} = \frac{343}{343 + 14} = \frac{343}{357} = 0.961$
#
# k-means is best for sensitivity
# - Sensitivity $= \frac{TP}{TP + FN} = \frac{165}{165 + (212 - 165)} = \frac{165}{165 + 47} = \frac{165}{212} = 0.778$

# %% [markdown]
# # 7. Prediction

# %%
#url <- "new_samples.csv"
url <- "https://tinyurl.com/new-samples-CSV"
new <- read.csv(url)
npc <- predict(wisc.pr, newdata=new)
npc
# Out:
#      PC1       PC2       PC3        PC4        PC5       PC6        PC7
# [1,]  2.576616 -3.135913  1.3990492 -0.7631950  2.781648 -0.8150185 -0.3959098
# [2,] -4.754928 -3.009033 -0.1660946 -0.6052952 -1.140698 -1.2189945  0.8193031
#      PC8        PC9       PC10       ⋯ PC21       PC22       PC23
# [1,] -0.2307350 0.1029569 -0.9272861 ⋯  0.1228233 0.09358453 0.08347651
# [2,] -0.3307423 0.5281896 -0.4855301 ⋯ -0.1224776 0.01732146 0.06316631
#      PC24       PC25        PC26         PC27         PC28        PC29
# [1,]  0.1223396  0.02124121  0.078884581  0.220199544 -0.02946023 -0.015620933
# [2,] -0.2338618 -0.20755948 -0.009833238 -0.001134152  0.09638361  0.002795349
#      PC30
# [1,]  0.005269029
# [2,] -0.019015820

# %%
plot(wisc.pr$x[,1:2], col=g)
points(npc[,1], npc[,2], col="blue", pch=16, cex=3)
text(npc[,1], npc[,2], c(1,2), col="white")
# Out:
# plot without title

# %% [markdown]
# ### Q18. Which of these new patients should we prioritize for follow up based on your results?
#
# Prioritize the new patients close or within the malignant clusters
